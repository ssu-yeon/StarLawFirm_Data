# %% [markdown]
# # [주제02] 검색 추이 비교 분석
# - 데이터 수집 시 [기간]은 1개월, 일간 으로 설정하여 진행합니다. 이 외 [범위]는 아래 내용 참고하여 각각 설정 후 진행하고, [성별], [연령선택] 은 기본값으로 둡니다.

# %% [markdown]
# ## 옵션 전부 비워둔 통합검색 추이 결과

# %% [markdown]
# ### 카테고리_1, 카테고리_2, 카테고리_3 각 카테고리별 비교

# %%
#-*- coding: utf-8 -*-
import os
import sys
import urllib.request
client_id = "BDAOBza0vG1y4xiaK0gu"
client_secret = "MmQ0qSa2JJ"
url = "https://openapi.naver.com/v1/datalab/search";
body = "{\"startDate\":\"2022-12-05\",\"endDate\":\"2023-01-05\",\"timeUnit\":\"date\",\"keywordGroups\":[{\"groupName\":\"회생\",\"keywords\":[\"회생\"]},{\"groupName\":\"이혼\",\"keywords\":[\"이혼\"]},{\"groupName\":\"음주\",\"keywords\":[\"음주\"]}],\"ages\":[\"1\",\"2\"],\"gender\":\"f\"}";

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    scraped = response_body.decode('utf-8')
else:
    print("Error Code:" + rescode)
    
result = json.loads(scraped)
result
# Out:
# {'startDate': '2022-12-05',
#  'endDate': '2023-01-05',
#  'timeUnit': 'date',
#  'results': [{'title': '회생',
#    'keywords': ['회생'],
#    'data': [{'period': '2022-12-05', 'ratio': 20},
#     {'period': '2022-12-06', 'ratio': 35},
#     {'period': '2022-12-07', 'ratio': 25},
#     {'period': '2022-12-08', 'ratio': 17.5},
#     {'period': '2022-12-09', 'ratio': 25},
#     {'period': '2022-12-10', 'ratio': 32.5},
#     {'period': '2022-12-11', 'ratio': 25},
#     {'period': '2022-12-12', 'ratio': 35},
#     {'period': '2022-12-13', 'ratio': 17.5},
#     {'period': '2022-12-14', 'ratio': 22.5},
#     {'period': '2022-12-15', 'ratio': 32.5},
#     {'period': '2022-12-16', 'ratio': 15},
#     {'period': '2022-12-17', 'ratio': 35},
#     {'period': '2022-12-18', 'ratio': 27.5},
#     {'period': '2022-12-19', 'ratio': 17.5},
#     {'period': '2022-12-20', 'ratio': 22.5},
#     {'period': '2022-12-21', 'ratio': 15},
#     {'period': '2022-12-22', 'ratio': 17.5},
# ...

# %% [markdown]
# ### 카테고리_1(회생) 내의 키워드1~키워드5끼리 비교

# %%
#-*- coding: utf-8 -*-
import os
import sys
import urllib.request
client_id = "BDAOBza0vG1y4xiaK0gu"
client_secret = "MmQ0qSa2JJ"
url = "https://openapi.naver.com/v1/datalab/search";
body = "{\"startDate\":\"2022-12-05\",\"endDate\":\"2023-01-05\",\"timeUnit\":\"date\",\"keywordGroups\":[{\"groupName\":\"회생\",\"keywords\":[\"개인회생\",\"대구개인회생\",\"대구개인회생전문\",\"개인회생신청자격\",\"개인회생전문\"]}],\"ages\":[\"1\",\"2\"],\"gender\":\"f\"}";

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    scraped = response_body.decode('utf-8')
else:
    print("Error Code:" + rescode)
    
result = json.loads(scraped)
result
# Out:
# {'startDate': '2022-12-05',
#  'endDate': '2023-01-05',
#  'timeUnit': 'date',
#  'results': [{'title': '회생',
#    'keywords': ['개인회생', '대구개인회생', '대구개인회생전문', '개인회생신청자격', '개인회생전문'],
#    'data': [{'period': '2022-12-05', 'ratio': 72.22222},
#     {'period': '2022-12-06', 'ratio': 44.44444},
#     {'period': '2022-12-07', 'ratio': 33.33333},
#     {'period': '2022-12-08', 'ratio': 61.11111},
#     {'period': '2022-12-09', 'ratio': 22.22222},
#     {'period': '2022-12-10', 'ratio': 66.66666},
#     {'period': '2022-12-11', 'ratio': 33.33333},
#     {'period': '2022-12-12', 'ratio': 33.33333},
#     {'period': '2022-12-13', 'ratio': 100},
#     {'period': '2022-12-14', 'ratio': 61.11111},
#     {'period': '2022-12-15', 'ratio': 88.88888},
#     {'period': '2022-12-16', 'ratio': 44.44444},
#     {'period': '2022-12-17', 'ratio': 33.33333},
#     {'period': '2022-12-18', 'ratio': 44.44444},
#     {'period': '2022-12-19', 'ratio': 22.22222},
# ...

# %% [markdown]
# ### 카테고리_2(이혼) 내의 키워드1~키워드5끼리 비교

# %%
#-*- coding: utf-8 -*-
import os
import sys
import urllib.request
client_id = "BDAOBza0vG1y4xiaK0gu"
client_secret = "MmQ0qSa2JJ"
url = "https://openapi.naver.com/v1/datalab/search";
body = "{\"startDate\":\"2022-12-05\",\"endDate\":\"2023-01-05\",\"timeUnit\":\"date\",\"keywordGroups\":[{\"groupName\":\"이혼\",\"keywords\":[\"대구이혼변호사\",\"대구이혼전문변호사\",\"대구이혼상담\",\"이혼전문변호사\",\"이혼변호사\"]}],\"ages\":[\"1\",\"2\"],\"gender\":\"f\"}";

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    scraped = response_body.decode('utf-8')
else:
    print("Error Code:" + rescode)
    
result = json.loads(scraped)
result
# Out:
# {'startDate': '2022-12-05',
#  'endDate': '2023-01-05',
#  'timeUnit': 'date',
#  'results': [{'title': '이혼',
#    'keywords': ['대구이혼변호사', '대구이혼전문변호사', '대구이혼상담', '이혼전문변호사', '이혼변호사'],
#    'data': [{'period': '2022-12-05', 'ratio': 50},
#     {'period': '2022-12-06', 'ratio': 16.66666},
#     {'period': '2022-12-07', 'ratio': 50},
#     {'period': '2022-12-08', 'ratio': 83.33333},
#     {'period': '2022-12-11', 'ratio': 83.33333},
#     {'period': '2022-12-12', 'ratio': 16.66666},
#     {'period': '2022-12-13', 'ratio': 83.33333},
#     {'period': '2022-12-16', 'ratio': 33.33333},
#     {'period': '2022-12-17', 'ratio': 50},
#     {'period': '2022-12-18', 'ratio': 83.33333},
#     {'period': '2022-12-19', 'ratio': 50},
#     {'period': '2022-12-20', 'ratio': 33.33333},
#     {'period': '2022-12-21', 'ratio': 66.66666},
#     {'period': '2022-12-23', 'ratio': 100},
#     {'period': '2022-12-24', 'ratio': 66.66666},
#     {'period': '2022-12-26', 'ratio': 16.66666},
# ...

# %% [markdown]
# ### 카테고리_3(음주) 내의 키워드1~키워드5끼리 비교

# %%
#-*- coding: utf-8 -*-
import os
import sys
import urllib.request
client_id = "BDAOBza0vG1y4xiaK0gu"
client_secret = "MmQ0qSa2JJ"
url = "https://openapi.naver.com/v1/datalab/search";
body = "{\"startDate\":\"2022-12-05\",\"endDate\":\"2023-01-05\",\"timeUnit\":\"date\",\"keywordGroups\":[{\"groupName\":\"음주\",\"keywords\":[\"음주운전\",\"음주행정\",\"음주형사\",\"대구음주운전전문\",\"음주운전변호사\"]}],\"ages\":[\"1\",\"2\"],\"gender\":\"f\"}";

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    scraped = response_body.decode('utf-8')
else:
    print("Error Code:" + rescode)
    
result = json.loads(scraped)
result
# Out:
# {'startDate': '2022-12-05',
#  'endDate': '2023-01-05',
#  'timeUnit': 'date',
#  'results': [{'title': '음주',
#    'keywords': ['음주운전', '음주행정', '음주형사', '대구음주운전전문', '음주운전변호사'],
#    'data': [{'period': '2022-12-05', 'ratio': 21.90476},
#     {'period': '2022-12-06', 'ratio': 17.77777},
#     {'period': '2022-12-07', 'ratio': 21.5873},
#     {'period': '2022-12-08', 'ratio': 100},
#     {'period': '2022-12-09', 'ratio': 65.07936},
#     {'period': '2022-12-10', 'ratio': 36.82539},
#     {'period': '2022-12-11', 'ratio': 15.23809},
#     {'period': '2022-12-12', 'ratio': 12.38095},
#     {'period': '2022-12-13', 'ratio': 10.47619},
#     {'period': '2022-12-14', 'ratio': 8.57142},
#     {'period': '2022-12-15', 'ratio': 6.98412},
#     {'period': '2022-12-16', 'ratio': 12.38095},
#     {'period': '2022-12-17', 'ratio': 7.30158},
#     {'period': '2022-12-18', 'ratio': 6.03174},
#     {'period': '2022-12-19', 'ratio': 8.88888},
#     {'period': '2022-12-20', 'ratio': 32.38095},
# ...

# %% [markdown]
# ## PC 검색 추이 결과

# %% [markdown]
# ### 카테고리_1, 카테고리_2, 카테고리_3 각 카테고리별 비교

# %%
#-*- coding: utf-8 -*-
import os
import sys
import urllib.request
client_id = "BDAOBza0vG1y4xiaK0gu"
client_secret = "MmQ0qSa2JJ"
url = "https://openapi.naver.com/v1/datalab/search";
body = "{\"startDate\":\"2022-12-05\",\"endDate\":\"2023-01-05\",\"timeUnit\":\"date\",\"keywordGroups\":[{\"groupName\":\"회생\",\"keywords\":[\"회생\"]},{\"groupName\":\"이혼\",\"keywords\":[\"이혼\"]},{\"groupName\":\"음주\",\"keywords\":[\"음주\"]}],\"device\":\"pc\",\"ages\":[\"1\",\"2\"],\"gender\":\"f\"}";

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    scraped = response_body.decode('utf-8')
else:
    print("Error Code:" + rescode)
    
result = json.loads(scraped)
result
# Out:
# {'startDate': '2022-12-05',
#  'endDate': '2023-01-05',
#  'timeUnit': 'date',
#  'results': [{'title': '회생',
#    'keywords': ['회생'],
#    'data': [{'period': '2022-12-09', 'ratio': 50},
#     {'period': '2022-12-12', 'ratio': 50},
#     {'period': '2022-12-19', 'ratio': 25},
#     {'period': '2022-12-20', 'ratio': 25},
#     {'period': '2022-12-21', 'ratio': 25},
#     {'period': '2022-12-26', 'ratio': 25},
#     {'period': '2022-12-28', 'ratio': 25},
#     {'period': '2022-12-31', 'ratio': 25},
#     {'period': '2023-01-05', 'ratio': 25}]},
#   {'title': '이혼',
#    'keywords': ['이혼'],
#    'data': [{'period': '2022-12-07', 'ratio': 50},
#     {'period': '2022-12-08', 'ratio': 25},
#     {'period': '2022-12-10', 'ratio': 25},
#     {'period': '2022-12-11', 'ratio': 25},
#     {'period': '2022-12-13', 'ratio': 25},
#     {'period': '2022-12-15', 'ratio': 25},
#     {'period': '2022-12-17', 'ratio': 25},
#     {'period': '2022-12-18', 'ratio': 25},
# ...

# %% [markdown]
# ### 카테고리_1(회생) 내의 키워드1~키워드5끼리 비교

# %%
#-*- coding: utf-8 -*-
import os
import sys
import urllib.request
client_id = "BDAOBza0vG1y4xiaK0gu"
client_secret = "MmQ0qSa2JJ"
url = "https://openapi.naver.com/v1/datalab/search";
body = "{\"startDate\":\"2022-12-05\",\"endDate\":\"2023-01-05\",\"timeUnit\":\"date\",\"keywordGroups\":[{\"groupName\":\"회생\",\"keywords\":[\"개인회생\",\"대구개인회생\",\"대구개인회생전문\",\"개인회생신청자격\",\"개인회생전문\"]}],\"device\":\"pc\",\"ages\":[\"1\",\"2\"],\"gender\":\"f\"}";

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    scraped = response_body.decode('utf-8')
else:
    print("Error Code:" + rescode)
    
result = json.loads(scraped)
result
# Out:
# {'startDate': '2022-12-05',
#  'endDate': '2023-01-05',
#  'timeUnit': 'date',
#  'results': [{'title': '회생',
#    'keywords': ['개인회생', '대구개인회생', '대구개인회생전문', '개인회생신청자격', '개인회생전문'],
#    'data': [{'period': '2022-12-05', 'ratio': 66.66666},
#     {'period': '2022-12-10', 'ratio': 33.33333},
#     {'period': '2022-12-12', 'ratio': 66.66666},
#     {'period': '2022-12-13', 'ratio': 33.33333},
#     {'period': '2022-12-14', 'ratio': 33.33333},
#     {'period': '2022-12-15', 'ratio': 66.66666},
#     {'period': '2022-12-18', 'ratio': 66.66666},
#     {'period': '2022-12-20', 'ratio': 100},
#     {'period': '2022-12-22', 'ratio': 66.66666},
#     {'period': '2022-12-27', 'ratio': 66.66666},
#     {'period': '2022-12-28', 'ratio': 33.33333},
#     {'period': '2023-01-03', 'ratio': 33.33333},
#     {'period': '2023-01-04', 'ratio': 33.33333}]}]}

# %% [markdown]
# ### 카테고리_2(이혼) 내의 키워드1~키워드5끼리 비교

# %%
#-*- coding: utf-8 -*-
import os
import sys
import urllib.request
client_id = "BDAOBza0vG1y4xiaK0gu"
client_secret = "MmQ0qSa2JJ"
url = "https://openapi.naver.com/v1/datalab/search";
body = "{\"startDate\":\"2022-12-05\",\"endDate\":\"2023-01-05\",\"timeUnit\":\"date\",\"keywordGroups\":[{\"groupName\":\"이혼\",\"keywords\":[\"대구이혼변호사\",\"대구이혼전문변호사\",\"대구이혼상담\",\"이혼전문변호사\",\"이혼변호사\"]}],\"device\":\"pc\",\"ages\":[\"1\",\"2\"],\"gender\":\"f\"}";

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    scraped = response_body.decode('utf-8')
else:
    print("Error Code:" + rescode)
    
result = json.loads(scraped)
result
# Out:
# {'startDate': '2022-12-05',
#  'endDate': '2023-01-05',
#  'timeUnit': 'date',
#  'results': [{'title': '이혼',
#    'keywords': ['대구이혼변호사', '대구이혼전문변호사', '대구이혼상담', '이혼전문변호사', '이혼변호사'],
#    'data': [{'period': '2022-12-19', 'ratio': 100},
#     {'period': '2022-12-20', 'ratio': 100},
#     {'period': '2022-12-28', 'ratio': 50}]}]}

# %% [markdown]
# ### 카테고리_3(음주) 내의 키워드1~키워드5끼리 비교

# %%
#-*- coding: utf-8 -*-
import os
import sys
import urllib.request
client_id = "BDAOBza0vG1y4xiaK0gu"
client_secret = "MmQ0qSa2JJ"
url = "https://openapi.naver.com/v1/datalab/search";
body = "{\"startDate\":\"2022-12-05\",\"endDate\":\"2023-01-05\",\"timeUnit\":\"date\",\"keywordGroups\":[{\"groupName\":\"음주\",\"keywords\":[\"음주운전\",\"음주행정\",\"음주형사\",\"대구음주운전전문\",\"음주운전변호사\"]}],\"device\":\"pc\",\"ages\":[\"1\",\"2\"],\"gender\":\"f\"}";

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    scraped = response_body.decode('utf-8')
else:
    print("Error Code:" + rescode)
    
result = json.loads(scraped)
result
# Out:
# {'startDate': '2022-12-05',
#  'endDate': '2023-01-05',
#  'timeUnit': 'date',
#  'results': [{'title': '음주',
#    'keywords': ['음주운전', '음주행정', '음주형사', '대구음주운전전문', '음주운전변호사'],
#    'data': [{'period': '2022-12-05', 'ratio': 50},
#     {'period': '2022-12-06', 'ratio': 50},
#     {'period': '2022-12-07', 'ratio': 100},
#     {'period': '2022-12-08', 'ratio': 25},
#     {'period': '2022-12-09', 'ratio': 50},
#     {'period': '2022-12-11', 'ratio': 25},
#     {'period': '2022-12-12', 'ratio': 25},
#     {'period': '2022-12-13', 'ratio': 50},
#     {'period': '2022-12-14', 'ratio': 25},
#     {'period': '2022-12-16', 'ratio': 25},
#     {'period': '2022-12-19', 'ratio': 75},
#     {'period': '2022-12-20', 'ratio': 100},
#     {'period': '2022-12-21', 'ratio': 25},
#     {'period': '2022-12-22', 'ratio': 75},
#     {'period': '2022-12-23', 'ratio': 25},
#     {'period': '2022-12-26', 'ratio': 75},
#     {'period': '2022-12-28', 'ratio': 25},
#     {'period': '2022-12-30', 'ratio': 75},
# ...

# %% [markdown]
# ## 모바일 검색 추이 결과

# %% [markdown]
# ### 카테고리_1, 카테고리_2, 카테고리_3 각 카테고리별 비교

# %%
#-*- coding: utf-8 -*-
import os
import sys
import urllib.request
client_id = "BDAOBza0vG1y4xiaK0gu"
client_secret = "MmQ0qSa2JJ"
url = "https://openapi.naver.com/v1/datalab/search";
body = "{\"startDate\":\"2022-12-05\",\"endDate\":\"2023-01-05\",\"timeUnit\":\"date\",\"keywordGroups\":[{\"groupName\":\"회생\",\"keywords\":[\"회생\"]},{\"groupName\":\"이혼\",\"keywords\":[\"이혼\"]},{\"groupName\":\"음주\",\"keywords\":[\"음주\"]}],\"device\":\"mo\",\"ages\":[\"1\",\"2\"],\"gender\":\"f\"}";

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    scraped = response_body.decode('utf-8')
else:
    print("Error Code:" + rescode)
    
result = json.loads(scraped)
result
# Out:
# {'startDate': '2022-12-05',
#  'endDate': '2023-01-05',
#  'timeUnit': 'date',
#  'results': [{'title': '회생',
#    'keywords': ['회생'],
#    'data': [{'period': '2022-12-05', 'ratio': 20},
#     {'period': '2022-12-06', 'ratio': 35},
#     {'period': '2022-12-07', 'ratio': 25},
#     {'period': '2022-12-08', 'ratio': 17.5},
#     {'period': '2022-12-09', 'ratio': 20},
#     {'period': '2022-12-10', 'ratio': 32.5},
#     {'period': '2022-12-11', 'ratio': 25},
#     {'period': '2022-12-12', 'ratio': 30},
#     {'period': '2022-12-13', 'ratio': 17.5},
#     {'period': '2022-12-14', 'ratio': 22.5},
#     {'period': '2022-12-15', 'ratio': 32.5},
#     {'period': '2022-12-16', 'ratio': 15},
#     {'period': '2022-12-17', 'ratio': 35},
#     {'period': '2022-12-18', 'ratio': 27.5},
#     {'period': '2022-12-19', 'ratio': 15},
#     {'period': '2022-12-20', 'ratio': 20},
#     {'period': '2022-12-21', 'ratio': 12.5},
#     {'period': '2022-12-22', 'ratio': 17.5},
# ...

# %% [markdown]
# ### 카테고리_1(회생) 내의 키워드1~키워드5끼리 비교

# %%
#-*- coding: utf-8 -*-
import os
import sys
import urllib.request
client_id = "BDAOBza0vG1y4xiaK0gu"
client_secret = "MmQ0qSa2JJ"
url = "https://openapi.naver.com/v1/datalab/search";
body = "{\"startDate\":\"2022-12-05\",\"endDate\":\"2023-01-05\",\"timeUnit\":\"date\",\"keywordGroups\":[{\"groupName\":\"회생\",\"keywords\":[\"개인회생\",\"대구개인회생\",\"대구개인회생전문\",\"개인회생신청자격\",\"개인회생전문\"]}],\"device\":\"mo\",\"ages\":[\"1\",\"2\"],\"gender\":\"f\"}";

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    scraped = response_body.decode('utf-8')
else:
    print("Error Code:" + rescode)
    
result = json.loads(scraped)
result
# Out:
# {'startDate': '2022-12-05',
#  'endDate': '2023-01-05',
#  'timeUnit': 'date',
#  'results': [{'title': '회생',
#    'keywords': ['개인회생', '대구개인회생', '대구개인회생전문', '개인회생신청자격', '개인회생전문'],
#    'data': [{'period': '2022-12-05', 'ratio': 64.70588},
#     {'period': '2022-12-06', 'ratio': 47.05882},
#     {'period': '2022-12-07', 'ratio': 35.29411},
#     {'period': '2022-12-08', 'ratio': 64.70588},
#     {'period': '2022-12-09', 'ratio': 23.52941},
#     {'period': '2022-12-10', 'ratio': 64.70588},
#     {'period': '2022-12-11', 'ratio': 35.29411},
#     {'period': '2022-12-12', 'ratio': 23.52941},
#     {'period': '2022-12-13', 'ratio': 100},
#     {'period': '2022-12-14', 'ratio': 58.82352},
#     {'period': '2022-12-15', 'ratio': 82.35294},
#     {'period': '2022-12-16', 'ratio': 47.05882},
#     {'period': '2022-12-17', 'ratio': 35.29411},
#     {'period': '2022-12-18', 'ratio': 35.29411},
#     {'period': '2022-12-19', 'ratio': 23.52941},
# ...

# %% [markdown]
# ### 카테고리_2(이혼) 내의 키워드1~키워드5끼리 비교

# %%
#-*- coding: utf-8 -*-
import os
import sys
import urllib.request
client_id = "BDAOBza0vG1y4xiaK0gu"
client_secret = "MmQ0qSa2JJ"
url = "https://openapi.naver.com/v1/datalab/search";
body = "{\"startDate\":\"2022-12-05\",\"endDate\":\"2023-01-05\",\"timeUnit\":\"date\",\"keywordGroups\":[{\"groupName\":\"이혼\",\"keywords\":[\"대구이혼변호사\",\"대구이혼전문변호사\",\"대구이혼상담\",\"이혼전문변호사\",\"이혼변호사\"]}],\"device\":\"mo\",\"ages\":[\"1\",\"2\"],\"gender\":\"f\"}";

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    scraped = response_body.decode('utf-8')
else:
    print("Error Code:" + rescode)
    
result = json.loads(scraped)
result
# Out:
# {'startDate': '2022-12-05',
#  'endDate': '2023-01-05',
#  'timeUnit': 'date',
#  'results': [{'title': '이혼',
#    'keywords': ['대구이혼변호사', '대구이혼전문변호사', '대구이혼상담', '이혼전문변호사', '이혼변호사'],
#    'data': [{'period': '2022-12-05', 'ratio': 50},
#     {'period': '2022-12-06', 'ratio': 16.66666},
#     {'period': '2022-12-07', 'ratio': 50},
#     {'period': '2022-12-08', 'ratio': 83.33333},
#     {'period': '2022-12-11', 'ratio': 83.33333},
#     {'period': '2022-12-12', 'ratio': 16.66666},
#     {'period': '2022-12-13', 'ratio': 83.33333},
#     {'period': '2022-12-16', 'ratio': 33.33333},
#     {'period': '2022-12-17', 'ratio': 50},
#     {'period': '2022-12-18', 'ratio': 83.33333},
#     {'period': '2022-12-19', 'ratio': 16.66666},
#     {'period': '2022-12-21', 'ratio': 66.66666},
#     {'period': '2022-12-23', 'ratio': 100},
#     {'period': '2022-12-24', 'ratio': 66.66666},
#     {'period': '2022-12-26', 'ratio': 16.66666},
#     {'period': '2022-12-27', 'ratio': 33.33333},
# ...

# %% [markdown]
# ### 카테고리_3(음주) 내의 키워드1~키워드5끼리 비교

# %%
#-*- coding: utf-8 -*-
import os
import sys
import urllib.request
client_id = "BDAOBza0vG1y4xiaK0gu"
client_secret = "MmQ0qSa2JJ"
url = "https://openapi.naver.com/v1/datalab/search";
body = "{\"startDate\":\"2022-12-05\",\"endDate\":\"2023-01-05\",\"timeUnit\":\"date\",\"keywordGroups\":[{\"groupName\":\"음주\",\"keywords\":[\"음주운전\",\"음주행정\",\"음주형사\",\"대구음주운전전문\",\"음주운전변호사\"]}],\"device\":\"mo\",\"ages\":[\"1\",\"2\"],\"gender\":\"f\"}";

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    scraped = response_body.decode('utf-8')
else:
    print("Error Code:" + rescode)
    
result = json.loads(scraped)
result
# Out:
# {'startDate': '2022-12-05',
#  'endDate': '2023-01-05',
#  'timeUnit': 'date',
#  'results': [{'title': '음주',
#    'keywords': ['음주운전', '음주행정', '음주형사', '대구음주운전전문', '음주운전변호사'],
#    'data': [{'period': '2022-12-05', 'ratio': 21.33757},
#     {'period': '2022-12-06', 'ratio': 17.19745},
#     {'period': '2022-12-07', 'ratio': 20.38216},
#     {'period': '2022-12-08', 'ratio': 100},
#     {'period': '2022-12-09', 'ratio': 64.64968},
#     {'period': '2022-12-10', 'ratio': 36.94267},
#     {'period': '2022-12-11', 'ratio': 14.96815},
#     {'period': '2022-12-12', 'ratio': 12.10191},
#     {'period': '2022-12-13', 'ratio': 9.87261},
#     {'period': '2022-12-14', 'ratio': 8.28025},
#     {'period': '2022-12-15', 'ratio': 7.00636},
#     {'period': '2022-12-16', 'ratio': 12.10191},
#     {'period': '2022-12-17', 'ratio': 7.32484},
#     {'period': '2022-12-18', 'ratio': 6.05095},
#     {'period': '2022-12-19', 'ratio': 7.96178},
#     {'period': '2022-12-20', 'ratio': 31.21019},
# ...
